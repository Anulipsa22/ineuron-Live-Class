# %%
CLASS 22: PANDAS CONTD: 30TH JULY 2022
DATASET USED:

https://drive.google.com/file/d/1FRnbQqgK6S-mr9StNF5MurSaXhah9uoJ/view?usp=sharing

https://drive.google.com/file/d/11rPJXr-9VoeV2Pi0RSfVehw1tbQOAjLI/view?usp=sharing


import pandas as pd
df = pd.read_csv("/content/sample_data/sales_data_final.csv")
df.head(3) #Top 3 Rows
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	...	category	sub_category	product_name	sales	quantity	discount	profit	shipping_cost	order_priority	year
0	AG-2011-2040	1/1/2011	1/6/2011	Standard Class	Toby Braunhardt	Consumer	Constantine	Algeria	Africa	Africa	...	Office Supplies	Storage	Tenex Lockers, Blue	408	2	0.0	106.140	35.46	Medium	2011
1	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	...	Office Supplies	Supplies	Acme Trimmer, High Speed	120	3	0.1	36.036	9.72	Medium	2011
2	HU-2011-1220	1/1/2011	1/5/2011	Second Class	Annie Thurman	Consumer	Budapest	Hungary	EMEA	EMEA	...	Office Supplies	Storage	Tenex Box, Single Width	66	4	0.0	29.640	8.17	High	2011
3 rows × 21 columns

df.tail(3) #Last 3 Rows
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	...	category	sub_category	product_name	sales	quantity	discount	profit	shipping_cost	order_priority	year
51287	MX-2014-110527	12/31/2014	1/2/2015	Second Class	Charlotte Melton	Consumer	Managua	Nicaragua	LATAM	Central	...	Office Supplies	Labels	Hon Color Coded Labels, 5000 Label Set	26	3	0.0	12.3600	0.35	Medium	2014
51288	MX-2014-114783	12/31/2014	1/6/2015	Standard Class	Tamara Dahlen	Consumer	Chihuahua	Mexico	LATAM	North	...	Office Supplies	Labels	Hon Legal Exhibit Labels, Alphabetical	7	1	0.0	0.5600	0.20	Medium	2014
51289	CA-2014-156720	12/31/2014	1/4/2015	Standard Class	Jill Matthias	Consumer	Colorado	United States	US	West	...	Office Supplies	Fasteners	Bagged Rubber Bands	3	3	0.2	-0.6048	0.17	Medium	2014
3 rows × 21 columns

df.columns #List of all columns
Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
       'segment', 'state', 'country', 'market', 'region', 'product_id',
       'category', 'sub_category', 'product_name', 'sales', 'quantity',
       'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
      dtype='object')
df['order_date'] #Extracting Single Column
0          1/1/2011
1          1/1/2011
2          1/1/2011
3          1/1/2011
4          1/1/2011
            ...    
51285    12/31/2014
51286    12/31/2014
51287    12/31/2014
51288    12/31/2014
51289    12/31/2014
Name: order_date, Length: 51290, dtype: object
type(df['order_date']) #Series (Equivalent to list). Pandas has only 2 data types: Series and DataFrame
pandas.core.series.Series
df.dtypes #Data Types
order_id           object
order_date         object
ship_date          object
ship_mode          object
customer_name      object
segment            object
state              object
country            object
market             object
region             object
product_id         object
category           object
sub_category       object
product_name       object
sales              object
quantity            int64
discount          float64
profit            float64
shipping_cost     float64
order_priority     object
year                int64
dtype: object
df['profit']
0        106.1400
1         36.0360
2         29.6400
3        -26.0550
4         37.7700
           ...   
51285      4.5188
51286      0.4200
51287     12.3600
51288      0.5600
51289     -0.6048
Name: profit, Length: 51290, dtype: float64
df[['profit','year']] #Fetching Multiple Columns
profit	year
0	106.1400	2011
1	36.0360	2011
2	29.6400	2011
3	-26.0550	2011
4	37.7700	2011
...	...	...
51285	4.5188	2014
51286	0.4200	2014
51287	12.3600	2014
51288	0.5600	2014
51289	-0.6048	2014
51290 rows × 2 columns

type([[df['profit']]]) #For multiple columns fetching, we need to pass as a list otherwise we will get an error
list
type(df['profit'])
pandas.core.series.Series
df.columns
Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
       'segment', 'state', 'country', 'market', 'region', 'product_id',
       'category', 'sub_category', 'product_name', 'sales', 'quantity',
       'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
      dtype='object')
df[['order_id','product_id','quantity']]
order_id	product_id	quantity
0	AG-2011-2040	OFF-TEN-10000025	2
1	IN-2011-47883	OFF-SU-10000618	3
2	HU-2011-1220	OFF-TEN-10001585	4
3	IT-2011-3647632	OFF-PA-10001492	3
4	IN-2011-47883	FUR-FU-10003447	5
...	...	...	...
51285	CA-2014-115427	OFF-BI-10002103	2
51286	MO-2014-2560	OFF-WIL-10001069	1
51287	MX-2014-110527	OFF-LA-10004182	3
51288	MX-2014-114783	OFF-LA-10000413	1
51289	CA-2014-156720	OFF-FA-10003472	3
51290 rows × 3 columns

df.describe() #Descriptive Statistics of Data: Only about integer and Float data types, description will be mentioned
#Count here shows that there is no Null Values for the columns mentioned
#Pandas Profiling will give us detailed analytics on the data by using a single line of code
#Standard Deviation: Deviation from Mean: Root of Variance
#25th Percentile Data: Data is arranged in ascending order and then 25th percent of data
quantity	discount	profit	shipping_cost	year
count	51290.000000	51290.000000	51290.000000	51290.000000	51290.000000
mean	3.476545	0.142908	28.641740	26.375915	2012.777208
std	2.278766	0.212280	174.424113	57.296804	1.098931
min	1.000000	0.000000	-6599.978000	0.000000	2011.000000
25%	2.000000	0.000000	0.000000	2.610000	2012.000000
50%	3.000000	0.000000	9.240000	7.790000	2013.000000
75%	5.000000	0.200000	36.810000	24.450000	2014.000000
max	14.000000	0.850000	8399.976000	933.570000	2014.000000
df.dtypes == 'object'
order_id           True
order_date         True
ship_date          True
ship_mode          True
customer_name      True
segment            True
state              True
country            True
market             True
region             True
product_id         True
category           True
sub_category       True
product_name       True
sales              True
quantity          False
discount          False
profit            False
shipping_cost     False
order_priority     True
year              False
dtype: bool
type(df.dtypes) #series (Like List)
pandas.core.series.Series
df.dtypes[df.dtypes == 'object'] #Only Object data type shown
order_id          object
order_date        object
ship_date         object
ship_mode         object
customer_name     object
segment           object
state             object
country           object
market            object
region            object
product_id        object
category          object
sub_category      object
product_name      object
sales             object
order_priority    object
dtype: object
df.dtypes[df.dtypes == 'object'].index #List of all the columns having data type object. This statement outputs a list
Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
       'segment', 'state', 'country', 'market', 'region', 'product_id',
       'category', 'sub_category', 'product_name', 'sales', 'order_priority'],
      dtype='object')
df[df.dtypes[df.dtypes == 'object'].index] #Passing List int the dataframe gives us the data with specific columns
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	product_id	category	sub_category	product_name	sales	order_priority
0	AG-2011-2040	1/1/2011	1/6/2011	Standard Class	Toby Braunhardt	Consumer	Constantine	Algeria	Africa	Africa	OFF-TEN-10000025	Office Supplies	Storage	Tenex Lockers, Blue	408	Medium
1	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	OFF-SU-10000618	Office Supplies	Supplies	Acme Trimmer, High Speed	120	Medium
2	HU-2011-1220	1/1/2011	1/5/2011	Second Class	Annie Thurman	Consumer	Budapest	Hungary	EMEA	EMEA	OFF-TEN-10001585	Office Supplies	Storage	Tenex Box, Single Width	66	High
3	IT-2011-3647632	1/1/2011	1/5/2011	Second Class	Eugene Moren	Home Office	Stockholm	Sweden	EU	North	OFF-PA-10001492	Office Supplies	Paper	Enermax Note Cards, Premium	45	High
4	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	FUR-FU-10003447	Furniture	Furnishings	Eldon Light Bulb, Duo Pack	114	Medium
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
51285	CA-2014-115427	12/31/2014	1/4/2015	Standard Class	Erica Bern	Corporate	California	United States	US	West	OFF-BI-10002103	Office Supplies	Binders	Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl	14	Medium
51286	MO-2014-2560	12/31/2014	1/5/2015	Standard Class	Liz Preis	Consumer	Souss-Massa-Draƒ	Morocco	Africa	Africa	OFF-WIL-10001069	Office Supplies	Binders	Wilson Jones Hole Reinforcements, Clear	4	Medium
51287	MX-2014-110527	12/31/2014	1/2/2015	Second Class	Charlotte Melton	Consumer	Managua	Nicaragua	LATAM	Central	OFF-LA-10004182	Office Supplies	Labels	Hon Color Coded Labels, 5000 Label Set	26	Medium
51288	MX-2014-114783	12/31/2014	1/6/2015	Standard Class	Tamara Dahlen	Consumer	Chihuahua	Mexico	LATAM	North	OFF-LA-10000413	Office Supplies	Labels	Hon Legal Exhibit Labels, Alphabetical	7	Medium
51289	CA-2014-156720	12/31/2014	1/4/2015	Standard Class	Jill Matthias	Consumer	Colorado	United States	US	West	OFF-FA-10003472	Office Supplies	Fasteners	Bagged Rubber Bands	3	Medium
51290 rows × 16 columns

df[df.dtypes[df.dtypes == 'object'].index].describe() #Description of Object Data type is possible
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	product_id	category	sub_category	product_name	sales	order_priority
count	51290	51290	51290	51290	51290	51290	51290	51290	51290	51290	51290	51290	51290	51290	51290	51290
unique	25035	1430	1464	4	795	3	1094	147	7	13	10292	3	17	3788	2246	4
top	CA-2014-100111	6/18/2014	11/22/2014	Standard Class	Muhammed Yedwab	Consumer	California	United States	APAC	Central	OFF-AR-10003651	Office Supplies	Binders	Staples	13	Medium
freq	14	135	130	30775	108	26518	2001	9994	11002	11117	35	31273	6152	227	589	29433
df[df.dtypes[df.dtypes == 'float'].index] #Fetching Data for Float Datatype
discount	profit	shipping_cost
0	0.0	106.1400	35.46
1	0.1	36.0360	9.72
2	0.0	29.6400	8.17
3	0.5	-26.0550	4.82
4	0.1	37.7700	4.70
...	...	...	...
51285	0.2	4.5188	0.89
51286	0.0	0.4200	0.49
51287	0.0	12.3600	0.35
51288	0.0	0.5600	0.20
51289	0.2	-0.6048	0.17
51290 rows × 3 columns

df.order_id
0           AG-2011-2040
1          IN-2011-47883
2           HU-2011-1220
3        IT-2011-3647632
4          IN-2011-47883
              ...       
51285     CA-2014-115427
51286       MO-2014-2560
51287     MX-2014-110527
51288     MX-2014-114783
51289     CA-2014-156720
Name: order_id, Length: 51290, dtype: object
df['order_id']
0           AG-2011-2040
1          IN-2011-47883
2           HU-2011-1220
3        IT-2011-3647632
4          IN-2011-47883
              ...       
51285     CA-2014-115427
51286       MO-2014-2560
51287     MX-2014-110527
51288     MX-2014-114783
51289     CA-2014-156720
Name: order_id, Length: 51290, dtype: object
df['order_id'][1:4] #List Operations can be done as Series is equivalent to list
1      IN-2011-47883
2       HU-2011-1220
3    IT-2011-3647632
Name: order_id, dtype: object
df['order_id'][1:40:2] #With jump Size
1       IN-2011-47883
3     IT-2011-3647632
5       IN-2011-47883
7       IN-2011-79397
9        IZ-2011-4680
11      IN-2011-65159
13      IN-2011-33652
15     MX-2011-160234
17      ID-2011-80230
19      ID-2011-12596
21       IR-2011-7690
23       TZ-2011-7370
25      IN-2011-65159
27     MX-2011-111255
29     MX-2011-158771
31     MX-2011-111255
33     US-2011-136007
35     MX-2011-159373
37    IT-2011-2942451
39      IN-2011-33036
Name: order_id, dtype: object
df['category']
0        Office Supplies
1        Office Supplies
2        Office Supplies
3        Office Supplies
4              Furniture
              ...       
51285    Office Supplies
51286    Office Supplies
51287    Office Supplies
51288    Office Supplies
51289    Office Supplies
Name: category, Length: 51290, dtype: object
df['category1'] = 'Gaurav'
df
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	...	sub_category	product_name	sales	quantity	discount	profit	shipping_cost	order_priority	year	category1
0	AG-2011-2040	1/1/2011	1/6/2011	Standard Class	Toby Braunhardt	Consumer	Constantine	Algeria	Africa	Africa	...	Storage	Tenex Lockers, Blue	408	2	0.0	106.1400	35.46	Medium	2011	Gaurav
1	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	...	Supplies	Acme Trimmer, High Speed	120	3	0.1	36.0360	9.72	Medium	2011	Gaurav
2	HU-2011-1220	1/1/2011	1/5/2011	Second Class	Annie Thurman	Consumer	Budapest	Hungary	EMEA	EMEA	...	Storage	Tenex Box, Single Width	66	4	0.0	29.6400	8.17	High	2011	Gaurav
3	IT-2011-3647632	1/1/2011	1/5/2011	Second Class	Eugene Moren	Home Office	Stockholm	Sweden	EU	North	...	Paper	Enermax Note Cards, Premium	45	3	0.5	-26.0550	4.82	High	2011	Gaurav
4	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	...	Furnishings	Eldon Light Bulb, Duo Pack	114	5	0.1	37.7700	4.70	Medium	2011	Gaurav
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
51285	CA-2014-115427	12/31/2014	1/4/2015	Standard Class	Erica Bern	Corporate	California	United States	US	West	...	Binders	Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl	14	2	0.2	4.5188	0.89	Medium	2014	Gaurav
51286	MO-2014-2560	12/31/2014	1/5/2015	Standard Class	Liz Preis	Consumer	Souss-Massa-Draƒ	Morocco	Africa	Africa	...	Binders	Wilson Jones Hole Reinforcements, Clear	4	1	0.0	0.4200	0.49	Medium	2014	Gaurav
51287	MX-2014-110527	12/31/2014	1/2/2015	Second Class	Charlotte Melton	Consumer	Managua	Nicaragua	LATAM	Central	...	Labels	Hon Color Coded Labels, 5000 Label Set	26	3	0.0	12.3600	0.35	Medium	2014	Gaurav
51288	MX-2014-114783	12/31/2014	1/6/2015	Standard Class	Tamara Dahlen	Consumer	Chihuahua	Mexico	LATAM	North	...	Labels	Hon Legal Exhibit Labels, Alphabetical	7	1	0.0	0.5600	0.20	Medium	2014	Gaurav
51289	CA-2014-156720	12/31/2014	1/4/2015	Standard Class	Jill Matthias	Consumer	Colorado	United States	US	West	...	Fasteners	Bagged Rubber Bands	3	3	0.2	-0.6048	0.17	Medium	2014	Gaurav
51290 rows × 22 columns

df.columns
Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
       'segment', 'state', 'country', 'market', 'region', 'product_id',
       'category', 'sub_category', 'product_name', 'sales', 'quantity',
       'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
       'category1'],
      dtype='object')
df['order_id'].isnull() #Data null or not
0        False
1        False
2        False
3        False
4        False
         ...  
51285    False
51286    False
51287    False
51288    False
51289    False
Name: order_id, Length: 51290, dtype: bool
df['order_id'].isnull().sum() #No Null Data present in the column
0
df1 = pd.read_csv("/content/sample_data/DressSales.csv")
df1.isnull()
Dress_ID	29/8/2013	31/8/2013	2/9/2013	4/9/2013	6/9/2013	8/9/2013	10/9/2013	12/9/2013	14/9/2013	...	Unnamed: 26	Unnamed: 27	Unnamed: 28	Unnamed: 29	Unnamed: 30	Unnamed: 31	Unnamed: 32	Unnamed: 33	Unnamed: 34	Unnamed: 35
0	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
1	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
2	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
3	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
4	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
495	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
496	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
497	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
498	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
499	False	False	False	False	False	False	False	False	False	False	...	True	True	True	True	True	True	True	True	True	True
500 rows × 36 columns

#We want customer Name who has maximum profit
df[df['profit']] == max(df['profit'])
---------------------------------------------------------------------------
KeyError                                  Traceback (most recent call last)
<ipython-input-35-699337a22f06> in <module>()
      1 #We want customer Name who has maximum profit
----> 2 df[df['profit']] == max(df['profit'])

/usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
   3462             if is_iterator(key):
   3463                 key = list(key)
-> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
   3465 
   3466         # take() does not accept boolean indexers

/usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
   1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
   1313 
-> 1314         self._validate_read_indexer(keyarr, indexer, axis)
   1315 
   1316         if needs_i8_conversion(ax.dtype) or isinstance(

/usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
   1372                 if use_interval_msg:
   1373                     key = list(key)
-> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
   1375 
   1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())

KeyError: "None of [Float64Index([  106.14,   36.036,    29.64,  -26.055,    37.77,   15.342,\n                  3.12,  110.412, -319.464,   253.32,\n              ...\n                  6.84,    6.475,     6.12,    25.38,     0.66,   4.5188,\n                  0.42,    12.36,     0.56,  -0.6048],\n             dtype='float64', length=51290)] are in the [columns]"
df['country'] == 'Sweden'
0        False
1        False
2        False
3         True
4        False
         ...  
51285    False
51286    False
51287    False
51288    False
51289    False
Name: country, Length: 51290, dtype: bool
len(df[df['country'] == 'Sweden'])
203
df[df['shipping_cost'] > 20]
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	...	sub_category	product_name	sales	quantity	discount	profit	shipping_cost	order_priority	year	category1
0	AG-2011-2040	1/1/2011	1/6/2011	Standard Class	Toby Braunhardt	Consumer	Constantine	Algeria	Africa	Africa	...	Storage	Tenex Lockers, Blue	408	2	0.0	106.140	35.46	Medium	2011	Gaurav
6	CA-2011-1510	1/2/2011	1/6/2011	Standard Class	Magdelene Morse	Consumer	Ontario	Canada	Canada	Canada	...	Machines	Okidata Inkjet, Wireless	314	1	0.0	3.120	24.10	Medium	2011	Gaurav
7	IN-2011-79397	1/3/2011	1/3/2011	Same Day	Kean Nguyen	Corporate	New South Wales	Australia	APAC	Oceania	...	Appliances	Hoover Microwave, White	276	1	0.1	110.412	125.32	Critical	2011	Gaurav
8	ID-2011-80230	1/3/2011	1/9/2011	Standard Class	Ken Lonsdale	Consumer	Auckland	New Zealand	APAC	Oceania	...	Copiers	Hewlett Wireless Fax, Laser	912	4	0.4	-319.464	107.10	Low	2011	Gaurav
9	IZ-2011-4680	1/3/2011	1/7/2011	Standard Class	Lindsay Williams	Corporate	Ninawa	Iraq	EMEA	EMEA	...	Chairs	Novimex Swivel Stool, Set of Two	667	4	0.0	253.320	81.26	High	2011	Gaurav
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
51241	ES-2014-3638865	12/31/2014	1/1/2015	First Class	Susan Vittorini	Consumer	England	United Kingdom	EU	North	...	Storage	Fellowes Shelving, Single Width	289	5	0.0	75.150	34.47	Critical	2014	Gaurav
51242	MX-2014-141712	12/31/2014	12/31/2014	Same Day	Rick Bensley	Home Office	Managua	Nicaragua	LATAM	Central	...	Chairs	Novimex Chairmat, Set of Two	78	2	0.0	35.920	25.16	Critical	2014	Gaurav
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
50781	CA-2014-147956	12/25/2014	1/1/2015	Standard Class	Alan Hwang	Consumer	Washington	United States	US	West	...	Storage	Office Impressions Heavy Duty Welded Shelving ...	1,004	6	0.00	0.000	121.83	Low	2014	Gaurav
50969	US-2014-120166	12/27/2014	12/31/2014	Standard Class	Frank Hawley	Corporate	Valle del Cauca	Colombia	LATAM	South	...	Tables	Barricks Training Table, Rectangular	842	5	0.20	-200.080	120.11	High	2014	Gaurav
50970	ES-2014-4296634	12/27/2014	1/2/2015	Standard Class	Harry Marie	Corporate	Brittany	France	EU	Central	...	Appliances	Hamilton Beach Microwave, White	1,010	4	0.10	-44.940	108.27	Low	2014	Gaurav
51034	ID-2014-68183	12/29/2014	12/31/2014	First Class	Adam Hart	Corporate	Victoria	Australia	APAC	Oceania	...	Appliances	Hoover Stove, Red	1,535	3	0.10	-102.411	255.42	Medium	2014	Gaurav
51153	ID-2014-51509	12/30/2014	1/1/2015	Second Class	Naresj Patel	Consumer	Australian Capital Territory	Australia	APAC	Oceania	...	Chairs	Harbour Creations Rocking Chair, Black	434	5	0.40	-166.470	124.63	Critical	2014	Gaurav
604 rows × 22 columns

df.dtypes #Date is being treated as String/Object
order_id           object
order_date         object
ship_date          object
ship_mode          object
customer_name      object
segment            object
state              object
country            object
market             object
region             object
product_id         object
category           object
sub_category       object
product_name       object
sales              object
quantity            int64
discount          float64
profit            float64
shipping_cost     float64
order_priority     object
year                int64
category1          object
dtype: object
#Converting into Date type Format
pd.to_datetime(df['order_date'])
0       2011-01-01
1       2011-01-01
2       2011-01-01
3       2011-01-01
4       2011-01-01
           ...    
51285   2014-12-31
51286   2014-12-31
51287   2014-12-31
51288   2014-12-31
51289   2014-12-31
Name: order_date, Length: 51290, dtype: datetime64[ns]
date = pd.to_datetime(df['order_date'])
date
0       2011-01-01
1       2011-01-01
2       2011-01-01
3       2011-01-01
4       2011-01-01
           ...    
51285   2014-12-31
51286   2014-12-31
51287   2014-12-31
51288   2014-12-31
51289   2014-12-31
Name: order_date, Length: 51290, dtype: datetime64[ns]
type(date[0])
pandas._libs.tslibs.timestamps.Timestamp
df['converted_order_date'] = pd.to_datetime(df['order_date'])
  df
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	...	product_name	sales	quantity	discount	profit	shipping_cost	order_priority	year	category1	converted_order_date
0	AG-2011-2040	1/1/2011	1/6/2011	Standard Class	Toby Braunhardt	Consumer	Constantine	Algeria	Africa	Africa	...	Tenex Lockers, Blue	408	2	0.0	106.1400	35.46	Medium	2011	Gaurav	2011-01-01
1	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	...	Acme Trimmer, High Speed	120	3	0.1	36.0360	9.72	Medium	2011	Gaurav	2011-01-01
2	HU-2011-1220	1/1/2011	1/5/2011	Second Class	Annie Thurman	Consumer	Budapest	Hungary	EMEA	EMEA	...	Tenex Box, Single Width	66	4	0.0	29.6400	8.17	High	2011	Gaurav	2011-01-01
3	IT-2011-3647632	1/1/2011	1/5/2011	Second Class	Eugene Moren	Home Office	Stockholm	Sweden	EU	North	...	Enermax Note Cards, Premium	45	3	0.5	-26.0550	4.82	High	2011	Gaurav	2011-01-01
4	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	...	Eldon Light Bulb, Duo Pack	114	5	0.1	37.7700	4.70	Medium	2011	Gaurav	2011-01-01
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
51285	CA-2014-115427	12/31/2014	1/4/2015	Standard Class	Erica Bern	Corporate	California	United States	US	West	...	Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl	14	2	0.2	4.5188	0.89	Medium	2014	Gaurav	2014-12-31
51286	MO-2014-2560	12/31/2014	1/5/2015	Standard Class	Liz Preis	Consumer	Souss-Massa-Draƒ	Morocco	Africa	Africa	...	Wilson Jones Hole Reinforcements, Clear	4	1	0.0	0.4200	0.49	Medium	2014	Gaurav	2014-12-31
discount', 'profit', 'shipping_cost', 'order_priority', 'year',
       'category1', 'converted_order_date', 'order_date_year',
       'order_date_month', 'order_date_week'],
      dtype='object')
df[['converted_order_date','order_date_week']] #Showing jan as 52nd week and December as 1st Week. 
#So basically it shows how much week is left for the year
converted_order_date	order_date_week
0	2011-01-01	52
1	2011-01-01	52
2	2011-01-01	52
3	2011-01-01	52
4	2011-01-01	52
...	...	...
51285	2014-12-31	1
51286	2014-12-31	1
51287	2014-12-31	1
51288	2014-12-31	1
51289	2014-12-31	1
51290 rows × 2 columns

#In which month, we are going to do most sales --> Group by operation on month and then count
#In Pandas, this is equivalent to value_counts function
df['order_date_month'].value_counts()
11    6342
12    6302
9     5975
6     5331
8     5078
10    4490
5     3747
7     3166
4     3057
3     3035
1     2599
2     2168
Name: order_date_month, dtype: int64
df.columns
Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
       'segment', 'state', 'country', 'market', 'region', 'product_id',
       'category', 'sub_category', 'product_name', 'sales', 'quantity',
       'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
       'category1', 'converted_order_date', 'order_date_year',
       'order_date_month', 'order_date_week'],
      dtype='object')
#Cost to Company Computation
df['cost_to_company'] = df['discount'] + df['shipping_cost']
df.head()
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	...	profit	shipping_cost	order_priority	year	category1	converted_order_date	order_date_year	order_date_month	order_date_week	cost_to_company
0	AG-2011-2040	1/1/2011	1/6/2011	Standard Class	Toby Braunhardt	Consumer	Constantine	Algeria	Africa	Africa	...	106.140	35.46	Medium	2011	Gaurav	2011-01-01	2011	1	52	35.46
1	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	...	36.036	9.72	Medium	2011	Gaurav	2011-01-01	2011	1	52	9.82
2	HU-2011-1220	1/1/2011	1/5/2011	Second Class	Annie Thurman	Consumer	Budapest	Hungary	EMEA	EMEA	...	29.640	8.17	High	2011	Gaurav	2011-01-01	2011	1	52	8.17
3	IT-2011-3647632	1/1/2011	1/5/2011	Second Class	Eugene Moren	Home Office	Stockholm	Sweden	EU	North	...	-26.055	4.82	High	2011	Gaurav	2011-01-01	2011	1	52	5.32
4	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	...	37.770	4.70	Medium	2011	Gaurav	2011-01-01	2011	1	52	4.80
5 rows × 27 columns

df[df['cost_to_company'] == max(df['cost_to_company'])]['product_name']
13891    Plantronics CS510 - Over-the-Head monaural Wir...
Name: product_name, dtype: object
#Dropping Column
df.drop('cost_to_company',axis=1,inplace=True) #Column deleted permanently because of inplace=True, axis = 1 means column operation
df.drop(1) #Delete row 1 with index. Still we have 1st row when we display df
df
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	...	discount	profit	shipping_cost	order_priority	year	category1	converted_order_date	order_date_year	order_date_month	order_date_week
0	AG-2011-2040	1/1/2011	1/6/2011	Standard Class	Toby Braunhardt	Consumer	Constantine	Algeria	Africa	Africa	...	0.0	106.1400	35.46	Medium	2011	Gaurav	2011-01-01	2011	1	52
1	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	...	0.1	36.0360	9.72	Medium	2011	Gaurav	2011-01-01	2011	1	52
2	HU-2011-1220	1/1/2011	1/5/2011	Second Class	Annie Thurman	Consumer	Budapest	Hungary	EMEA	EMEA	...	0.0	29.6400	8.17	High	2011	Gaurav	2011-01-01	2011	1	52
3	IT-2011-3647632	1/1/2011	1/5/2011	Second Class	Eugene Moren	Home Office	Stockholm	Sweden	EU	North	...	0.5	-26.0550	4.82	High	2011	Gaurav	2011-01-01	2011	1	52
4	IN-2011-47883	1/1/2011	1/8/2011	Standard Class	Joseph Holt	Consumer	New South Wales	Australia	APAC	Oceania	...	0.1	37.7700	4.70	Medium	2011	Gaurav	2011-01-01	2011	1	52
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
51285	CA-2014-115427	12/31/2014	1/4/2015	Standard Class	Erica Bern	Corporate	California	United States	US	West	...	0.2	4.5188	0.89	Medium	2014	Gaurav	2014-12-31	2014	12	1
51286	MO-2014-2560	12/31/2014	1/5/2015	Standard Class	Liz Preis	Consumer	Souss-Massa-Draƒ	Morocco	Africa	Africa	...	0.0	0.4200	0.49	Medium	2014	Gaurav	2014-12-31	2014	12	1
51287	MX-2014-110527	12/31/2014	1/2/2015	Second Class	Charlotte Melton	Consumer	Managua	Nicaragua	LATAM	Central	...	0.0	12.3600	0.35	Medium	2014	Gaurav	2014-12-31	2014	12	1
51288	MX-2014-114783	12/31/2014	1/6/2015	Standard Class	Tamara Dahlen	Consumer	Chihuahua	Mexico	LATAM	North	...	0.0	0.5600	0.20	Medium	2014	Gaurav	2014-12-31	2014	12	1
51289	CA-2014-156720	12/31/2014	1/4/2015	Standard Class	Jill Matthias	Consumer	Colorado	United States	US	West	...	0.2	-0.6048	0.17	Medium	2014	Gaurav	2014-12-31	2014	12	1
51290 rows × 26 columns

#To drop 1st row permanently
df.drop(1,inplace=True)
df
order_id	order_date	ship_date	ship_mode	customer_name	segment	state	country	market	region	...
.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')]
quantity              int64
discount            float64
profit              float64
shipping_cost       float64
year                  int64
order_date_year       int64
order_date_month      int64
order_date_week       int64
dtype: object
df2 = df[df.dtypes[(df.dtypes == 'float64' )| (df.dtypes == 'int64')].index]
df2
quantity	discount	profit	shipping_cost	year	order_date_year	order_date_month	order_date_week
0	2	0.0	106.1400	35.46	2011	2011	1	52
2	4	0.0	29.6400	8.17	2011	2011	1	52
3	3	0.5	-26.0550	4.82	2011	2011	1	52
4	5	0.1	37.7700	4.70	2011	2011	1	52
5	2	0.1	15.3420	1.80	2011	2011	1	52
...	...	...	...	...	...	...	...	...
51285	2	0.2	4.5188	0.89	2014	2014	12	1
51286	1	0.0	0.4200	0.49	2014	2014	12	1
51287	3	0.0	12.3600	0.35	2014	2014	12	1
51288	1	0.0	0.5600	0.20	2014	2014	12	1
51289	3	0.2	-0.6048	0.17	2014	2014	12	1
51289 rows × 8 columns

df2[df2>100]
quantity	discount	profit	shipping_cost	year	order_date_year	order_date_month	order_date_week
0	NaN	NaN	106.14	NaN	2011	2011	NaN	NaN
2	NaN	NaN	NaN	NaN	2011	2011	NaN	NaN
3	NaN	NaN	NaN	NaN	2011	2011	NaN	NaN
4	NaN	NaN	NaN	NaN	2011	2011	NaN	NaN
5	NaN	NaN	NaN	NaN	2011	2011	NaN	NaN
...	...	...	...	...	...	...	...	...
51285	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51286	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51287	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51288	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51289	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51289 rows × 8 columns

df3 = df2[df2 >100]
#Will drop if there is a single NA value in a row
df3.dropna() #If we want permanent delete then inplace = True needs to be used
quantity	discount	profit	shipping_cost	year	order_date_year	order_date_month	order_date_week
df3.dropna(thresh=5) #Require that many non NAN values to not delete that row
quantity	discount	profit	shipping_cost	year	order_date_year	order_date_month	order_date_week
df3
quantity	discount	profit	shipping_cost	year	order_date_year	order_date_month	order_date_week
0	NaN	NaN	106.14	NaN	2011	2011	NaN	NaN
2	NaN	NaN	NaN	NaN	2011	2011	NaN	NaN
3	NaN	NaN	NaN	NaN	2011	2011	NaN	NaN
4	NaN	NaN	NaN	NaN	2011	2011	NaN	NaN
5	NaN	NaN	NaN	NaN	2011	2011	NaN	NaN
...	...	...	...	...	...	...	...	...
51285	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51286	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51287	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51288	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51289	NaN	NaN	NaN	NaN	2014	2014	NaN	NaN
51289 rows × 8 columns

#Filling NAN values with 4
df3.fillna(value=4)
quantity	discount	profit	shipping_cost	year	order_date_year	order_date_month	order_date_week
0	4.0	4.0	106.14	4.0	2011	2011	4.0	4.0
2	4.0	4.0	4.00	4.0	2011	2011	4.0	4.0
3	4.0	4.0	4.00	4.0	2011	2011	4.0	4.0
4	4.0	4.0	4.00	4.0	2011	2011	4.0	4.0
5	4.0	4.0	4.00	4.0	2011	2011	4.0	4.0
...	...	...	...	...	...	...	...	...
51285	4.0	4.0	4.00	4.0	2014	2014	4.0	4.0
51286	4.0	4.0	4.00	4.0	2014	2014	4.0	4.0
51287	4.0	4.0	4.00	4.0	2014	2014	4.0	4.0
51288	4.0	4.0	4.00	4.0	2014	2014	4.0	4.0
51289	4.0	4.0	4.00	4.0	2014	2014	4.0	4.0
51289 rows × 8 columns

df3.fillna(value = df3['profit']).mean()
quantity                    NaN
discount                    NaN
profit               285.710477
shipping_cost        205.753790
year                2012.777243
order_date_year     2012.777243
order_date_month            NaN
order_date_week             NaN
dtype: float64
(df3['profit']).mean()
285.71047695983384
#Average Profit year wise
df.groupby('order_date_year')['profit'].mean()
order_date_year
2011    27.665308
2012    28.043722
2013    29.604519
2014    28.758540
Name: profit, dtype: float64
#Average Shipping Cost year wise
df.groupby('order_date_year')['shipping_cost'].mean()
order_date_year
2011    27.149201
2012    25.861329
2013    26.418577
2014    26.268197
Name: shipping_cost, dtype: float64
#Average Discount year wise
df.groupby('order_date_year')['discount'].mean()
order_date_year
2011    0.148193
2012    0.141286
2013    0.140265
2014    0.143291
Name: discount, dtype: float64
#Average Sales year wise
df['sales'] = df.sales.str.replace(',',"").astype(int) #Converting into integer
df.groupby('order_date_year')['sales'].mean()
order_date_year
2011    251.127153
2012    244.252235
2013    246.819335
2014    245.282129
Name: sales, dtype: float64
#Average Quantity year wise
df.groupby('order_date_year')['quantity'].mean()
order_date_year
2011    3.494498
2012    3.476647
2013    3.488369
2014    3.457989
Name: quantity, dtype: float64
#Total Quantity year wise
df.groupby('order_date_year')['quantity'].sum()
order_date_year
2011    31440
2012    38111
2013    48136
2014    60622
Name: quantity, dtype: int64
#Total Sales year wise
df.groupby('order_date_year')['sales'].sum()  #Sales and Quantity both are increasing. Good sign for business
order_date_year
2011    2259391
2012    2677493
2013    3405860
2014    4300041
Name: sales, dtype: int64
df.columns
Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
       'segment', 'state', 'country', 'market', 'region', 'product_id',
       'category', 'sub_category', 'product_name', 'sales', 'quantity',
       'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
       'category1', 'converted_order_date', 'order_date_year',
       'order_date_month', 'order_date_week'],
      dtype='object')
df[['country','market']]
country	market
0	Algeria	Africa
2	Hungary	EMEA
3	Sweden	EU
4	Australia	APAC
5	Australia	APAC
...	...	...
51285	United States	US
51286	Morocco	Africa
51287	Nicaragua	LATAM
51288	Mexico	LATAM
51289	United States	US
51289 rows × 2 columns

#CHALLENGES GIVEN

Dataset 1: Agent Performance Data from iNeuron (Real Dataset)

Dataset 2: Agent Login Report

https://docs.google.com/spreadsheets/d/1z4EWsGxw0YBQ1-51xZDxYNlB3ngJzg4t/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true

https://docs.google.com/spreadsheets/d/1z2n8aeFF5GoohQ3KCZw8bKogezpO9l4k/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true

TASKS:

For each and every agent, Find out the weekly average rating for each agent (They workfor 5 days a week and not 7 days. So be careful with that. System will generate 7 records for a week)
Total Working Days for each Agent from Agent Performance Report
Total Queries taken by Agents
Total Feedback received by Agents
Agent Name who have average rating between 3.5 to 4
Agent Name who have rating less than 3.5
Agent Name who have rating more than 4.5
How many feedback agents have received more than Average
Average Weekly Response Time for each agent
Average Weekly Resolution Time for each agent
List of All Agents Name
Percentage of Chat on which they have recieved a feedback
Total Contribution hour for each and every agents weekly basis from Login Report Data
Total Percentage of Active Hour for a month
# Out:
#   File "C:\Users\ANULIP~1\AppData\Local\Temp/ipykernel_2900/4189713401.py", line 1
#     CLASS 22: PANDAS CONTD: 30TH JULY 2022
#           ^
# SyntaxError: invalid syntax
