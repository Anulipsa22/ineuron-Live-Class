# %% [markdown]
# Datastax server not up and running. Hence we are doing Pandas Library instead of Cassandra. Cassandra (Document Database: CQL Cassandra Query Language) is similar to MongoDB
#
# Pandas Library is used for Data Manipulation/Aggregation purposes
#
# #Dataset Link: https://drive.google.com/drive/folders/1vdLTTFQczfXW5o__f1ce5WfDqfI5JYAF?usp=sharing
#
# We will be using Jupyter Notebook because here we can visualize data intuitively whereas we can't in Pycharm

# %%
##Importing Pandas Library
import pandas as pd

# %%
#Reading the Excel File Attribute Dataset.xlsx
attribute_data = pd.read_excel('C:\\Users\\Anulipsa pc\\Downloads\\Attribute DataSet.xlsx')
attribute_data
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# 1          Petal   natural     microfiber         NaN     ruffles
# 2           full   natural       polyster         NaN         NaN
# 3           full   natural           silk     chiffon  embroidary
# 4      butterfly   natural  chiffonfabric     chiffon         bow
# ..           ...       ...            ...         ...         ...
# 495         full   natural       polyster         NaN         NaN
# 496         full    empire         cotton         NaN         NaN
# 497         full    empire         cotton         NaN        lace
# 498    sleevless    empire           silk  broadcloth    applique
# 499        short    empire         cotton    Corduroy        lace
#
#     Pattern Type  Recommendation
# 0         animal               1
# 1         animal               0
# 2          print               0
# 3          print               1
# 4            dot               0
# ..           ...             ...
# 495        solid               1
# 496          NaN               0
# 497        solid               1
# 498        print               1
# 499        solid               0
#
# [500 rows x 14 columns]

# %%
type(attribute_data) #DataFrame

#Series is similar to list but not same
# Out:
# pandas.core.frame.DataFrame

# %%
attribute_data=pd.read_excel('C:\\Users\\Anulipsa pc\\Downloads\\Attribute DataSet.xlsx')

# %%
type(attribute_data)
# Out:
# pandas.core.frame.DataFrame

# %%
attribute_data
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# 1          Petal   natural     microfiber         NaN     ruffles
# 2           full   natural       polyster         NaN         NaN
# 3           full   natural           silk     chiffon  embroidary
# 4      butterfly   natural  chiffonfabric     chiffon         bow
# ..           ...       ...            ...         ...         ...
# 495         full   natural       polyster         NaN         NaN
# 496         full    empire         cotton         NaN         NaN
# 497         full    empire         cotton         NaN        lace
# 498    sleevless    empire           silk  broadcloth    applique
# 499        short    empire         cotton    Corduroy        lace
#
#     Pattern Type  Recommendation
# 0         animal               1
# 1         animal               0
# 2          print               0
# 3          print               1
# 4            dot               0
# ..           ...             ...
# 495        solid               1
# 496          NaN               0
# 497        solid               1
# 498        print               1
# 499        solid               0
#
# [500 rows x 14 columns]

# %%
pd.read_excel(r'C:\\Users\\Anulipsa pc\\Downloads\\Attribute DataSet.xlsx',sheet_name='lipa',header=None,names=['A','B','C'])
# Out:
#        A     B     C
# 0   ghgh  jhjh    jj
# 1   ghgh  jhjh  ghgg
# 2   ghgh  jhjh   nmm
# 3   ghgh  jhjh    n
# 4   ghgh  jhjh    mb
# 5   ghgh  jhjh    gf
# 6   ghgh  jhjh   uyg
# 7   ghgh  jhjh   kuh
# 8   ghgh  jhjh   NaN
# 9   ghgh   NaN   NaN
# 10  ghgh   NaN   NaN

# %%
pd.read_excel(r'C:\\Users\\Anulipsa pc\\Downloads\\Attribute DataSet.xlsx',sheet_name='bisoyi',header=None)
# Out:
#     0     1      2     3
# 0  sd   NaN    NaN   NaN
# 1  sd   NaN    dff   NaN
# 2  sd   NaN    NaN   NaN
# 3  sd   NaN    NaN  dfdf
# 4  sd  dfdf    NaN   NaN
# 5  sd   NaN    NaN   NaN
# 6  sd   NaN    NaN   NaN
# 7  sd   NaN  vxfdf   NaN

# %%
attribute_data.head(2)  #Will show first 2 records
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
attribute_data.head() #Will show first 5 records
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
attribute_data.tail() #Will show last 5 records
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
attribute_data.tail(2) #Will show last 2 records
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
pd.read_csv('haberman.csv',header=None)
# Out:
#       0   1  2  3
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
pd.read_csv('haberman.csv',header=None,names=['Age of patient',"Patient's year of operation",'Number of positive axillary nodes detected','Survival status' ])
# Out:
#      Age of patient  Patient's year of operation  \
# 0                30                           64
# 1                30                           62
# 2                30                           65
# 3                31                           59
# 4                31                           65
# ..              ...                          ...
# 301              75                           62
# 302              76                           67
# 303              77                           65
# 304              78                           65
# 305              83                           58
#
#      Number of positive axillary nodes detected  Survival status
# 0                                             1                1
# 1                                             3                1
# 2                                             0                1
# 3                                             2                1
# 4                                             4                1
# ..                                          ...              ...
# 301                                           1                1
# 302                                           0                1
# 303                                           3                1
# 304                                           1                2
# 305                                           2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv('haberman 1.csv')
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 300   75@62@1@1
# 301   76@67@0@1
# 302   77@65@3@1
# 303   78@65@1@2
# 304   83@58@2@2
#
# [305 rows x 1 columns]

# %%
#To fix above, we will use separator argument in pandas
pd.read_csv('haberman 1.csv',sep='@')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv")
# Out:
#            date  values.I2P  values.P2I  values.JPI
# 0    1996-04-01   -2.580556   -0.836444        63.3
# 1    1996-05-01   -2.882258   -1.972581        66.3
# 2    1996-06-01   -1.742778   -0.478778        59.7
# 3    1996-07-01   -0.397796   -1.574301        63.3
# 4    1996-08-01   -0.977151   -1.797312        63.8
# ..          ...         ...         ...         ...
# 112  2005-08-01   -2.144935   -1.646989        49.0
# 113  2005-09-01   -3.543270   -1.769889        49.9
# 114  2005-10-01   -4.500484   -2.309946        50.6
# 115  2005-11-01   -4.098556   -1.528611        57.4
# 116  2005-12-01   -5.797043   -2.872849        52.9
#
# [117 rows x 4 columns]

# %%
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
a=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]    #Accessing data from list a
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
#Reading json (Java Script Object Notation) format: Combination of Dictionaries: We can use json viewer online to understand json in better way
#Keys become our column Names and Row becomes our values of those keys 

json_data=pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
json_data
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/48781  1385771189
# 1   https://github.com/pandas-dev/pandas/issues/48780  1385750265
# 2   https://github.com/pandas-dev/pandas/issues/48779  1385660723
# 3   https://github.com/pandas-dev/pandas/issues/48778  1385637077
# 4   https://github.com/pandas-dev/pandas/issues/48777  1385202798
# 5     https://github.com/pandas-dev/pandas/pull/48776  1385159645
# 6     https://github.com/pandas-dev/pandas/pull/48775  1385129867
# 7     https://github.com/pandas-dev/pandas/pull/48774  1385125103
# 8     https://github.com/pandas-dev/pandas/pull/48772  1385027203
# 9     https://github.com/pandas-dev/pandas/pull/48771  1385017460
# 10    https://github.com/pandas-dev/pandas/pull/48770  1384968001
# 11  https://github.com/pandas-dev/pandas/issues/48767  1384934606
# 12  https://github.com/pandas-dev/pandas/issues/48766  1384856275
# 13  https://github.com/pandas-dev/pandas/issues/48765  1384814175
# 14    https://github.com/pandas-dev/pandas/pull/48764  1384800999
# 15  https://github.com/pandas-dev/pandas/issues/48763  1384789416
# 16  https://github.com/pandas-dev/pandas/issues/48762  1384767079
# 17    https://github.com/pandas-dev/pandas/pull/48761  1384717026
# 18    https://github.com/pandas-dev/pandas/pull/48760  1384676207
# 19    https://github.com/pandas-dev/pandas/pull/48759  1384664843
# 20  https://github.com/pandas-dev/pandas/issues/48758  1384652284
# 21  https://github.com/pandas-dev/pandas/issues/48757  1384640911
# 22    https://github.com/pandas-dev/pandas/pull/48756  1384598007
# 23  https://github.com/pandas-dev/pandas/issues/48754  1384450586
# 24    https://github.com/pandas-dev/pandas/pull/48753  1384447122
# 25    https://github.com/pandas-dev/pandas/pull/48752  1384443919
# 26    https://github.com/pandas-dev/pandas/pull/48751  1384351106
# 27  https://github.com/pandas-dev/pandas/issues/48749  1384282771
# 28    https://github.com/pandas-dev/pandas/pull/48748  1384278959
# 29  https://github.com/pandas-dev/pandas/issues/48746  1384265732
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85SmTC1   48781
# 1    I_kwDOAA0YD85SmN75   48780
# 2    I_kwDOAA0YD85Sl4Ez   48779
# 3    I_kwDOAA0YD85SlyTV   48778
# 4    I_kwDOAA0YD85SkIRu   48777
# 5   PR_kwDOAA0YD84_j82V   48776
# 6   PR_kwDOAA0YD84_j3jB   48775
# 7   PR_kwDOAA0YD84_j2tY   48774
# 8   PR_kwDOAA0YD84_jmv1   48772
# 9   PR_kwDOAA0YD84_jlNi   48771
# 10  PR_kwDOAA0YD84_jcsk   48770
# 11   I_kwDOAA0YD85SjGzO   48767
# 12   I_kwDOAA0YD85SizrT   48766
# 13   I_kwDOAA0YD85SipZf   48765
# 14  PR_kwDOAA0YD84_jAYU   48764
# 15   I_kwDOAA0YD85SijWo   48763
# 16   I_kwDOAA0YD85Sid5n   48762
# 17  PR_kwDOAA0YD84_iyHt   48761
# 18  PR_kwDOAA0YD84_irXw   48760
# 19  PR_kwDOAA0YD84_ipWL   48759
# 20   I_kwDOAA0YD85SiB38   48758
# 21   I_kwDOAA0YD85Sh_GP   48757
# 22  PR_kwDOAA0YD84_idHj   48756
# 23   I_kwDOAA0YD85ShQoa   48754
# 24  PR_kwDOAA0YD84_iAwL   48753
# 25  PR_kwDOAA0YD84_iAGO   48752
# 26  PR_kwDOAA0YD84_hrS3   48751
# 27   I_kwDOAA0YD85SgnqT   48749
# 28  PR_kwDOAA0YD84_hcD9   48748
# 29   I_kwDOAA0YD85SgjgE   48746
#
#                                                 title  ... closed_at  \
# 0                                               ENH:   ...       NaT
# 1   BUG: ExcelWriter.book - attribute not accessib...  ...       NaT
# 2     BUG: pd.offsets.MonthEnd() delevers wrong month  ...       NaT
# 3   BUG: Regression on pandas 1.5.0 using describe...  ...       NaT
# 4   DOC: Table Visualization/Styler Documentation ...  ...       NaT
# 5   ENH: Add option to use nullable dtypes in read...  ...       NaT
# 6                          DOC: Correct default color  ...       NaT
# 7   ENH: Raise ParserError instead of IndexError w...  ...       NaT
# 8                            BUG: Bug fix for GH48567  ...       NaT
# 9   DOC: Add docs for DataFrameGroupBy.fillna and ...  ...       NaT
# 10         added sytle in stylesheet for <blockquote>  ...       NaT
# 11  BUG: `pd.to_datetime()` fails to parse nanosec...  ...       NaT
# 12  ENH: find categorical code against categorical...  ...       NaT
# 13  BUG: df.plot(subplots=False) not drawing as ex...  ...       NaT
# 14    SAS7BDAT parser: Drop unused instance variables  ...       NaT
# 15      BUG: pd.Series.unstack with mixed names types  ...       NaT
# 16          DOC: Update color of icons for dark theme  ...       NaT
# 17    TYP: type all arguments with int default values  ...       NaT
# 18  REGR: groupby.size with axis=1 doesn't return ...  ...       NaT
# 19                                  pylint pre-commit  ...       NaT
# 20                      WEB: Add style for blockquote  ...       NaT
# 21  BUG: in describe() result, mean is to NaN or I...  ...       NaT
# 22  Updated docstring for MultiIndex.get_level_values  ...       NaT
# 23  BUG: DateOffset frequency decimals do not work...  ...       NaT
# 24                       WARN: Catch warning in tests  ...       NaT
# 25                             PERF: MultiIndex.union  ...       NaT
# 26        WEB: Update link to datapythonista blog url  ...       NaT
# 27  API/PERF: Don't reorder categoricals when grou...  ...       NaT
# 28         API: Change DTA/TDA add/sub to match numpy  ...       NaT
# 29  BUG: Platform-dependent stringification of Per...  ...       NaT
#
#    author_association active_lock_reason  \
# 0         CONTRIBUTOR                NaN
# 1                NONE                NaN
# 2                NONE                NaN
# 3                NONE                NaN
# 4                NONE                NaN
# 5              MEMBER                NaN
# 6         CONTRIBUTOR                NaN
# 7              MEMBER                NaN
# 8                NONE                NaN
# 9              MEMBER                NaN
# 10               NONE                NaN
# 11               NONE                NaN
# 12               NONE                NaN
# 13               NONE                NaN
# 14        CONTRIBUTOR                NaN
# 15               NONE                NaN
# 16             MEMBER                NaN
# 17        CONTRIBUTOR                NaN
# 18             MEMBER                NaN
# 19               NONE                NaN
# 20             MEMBER                NaN
# 21               NONE                NaN
# 22               NONE                NaN
# 23        CONTRIBUTOR                NaN
# 24             MEMBER                NaN
# 25        CONTRIBUTOR                NaN
# 26             MEMBER                NaN
# 27             MEMBER                NaN
# 28             MEMBER                NaN
# 29               NONE                NaN
#
#                                                  body  \
# 0   ### Feature Type\n\n- [X] Adding new functiona...
# 1   ### Pandas version checks\n\n- [X] I have chec...
# 2   ### Pandas version checks\n\n- [X] I have chec...
# 3   ### Pandas version checks\n\n- [X] I have chec...
# 4   ### Pandas version checks\n\n- [X] I have chec...
# 5   - [x] closes #36712 (Replace xxxx with the Git...
# 6   Default color is not always yellow\r\n\r\n- [X...
# 7   \r\n- [x] closes #16393 (Replace xxxx with the...
# 8   Groupby for Series fails if an entry of the in...
# 9   - [ ] closes #xxxx (Replace xxxx with the Gith...
# 10  Closes #48758\r\n\r\nadded styles for styleshe...
# 11  ### Pandas version checks\n\n- [X] I have chec...
# 12  ### Feature Type\n\n- [X] Adding new functiona...
# 13  ### Pandas version checks\n\n- [X] I have chec...
# 14  I'm suggesting this as an alternative to https...
# 15  ### Pandas version checks\r\n\r\n- [X] I have ...
# 16  The color of our icons in the docs don't look ...
# 17  This enables the last missing check from autot...
# 18  - [x] closes #48738 (Replace xxxx with the Git...
# 19  - [ ] closes #48737\r\n- [ ] All [code checks ...
# 20  Looks like when we have a `<blockquote>` tag i...
# 21  ### Pandas version checks\n\n- [X] I have chec...
# 22  The docstring read "maybe casted to", instead ...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 25  \r\n- [x] [Tests added and passed](https://pan...
# 26  The domain of my blog changed long ago, but se...
# 27  xref: https://github.com/dask/dask/pull/9486#i...
# 28                              Sits on top of #48743
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason draft  \
# 0                       NaN           NaN   NaN
# 1                       NaN           NaN   NaN
# 2                       NaN           NaN   NaN
# 3                       NaN           NaN   NaN
# 4                       NaN           NaN   NaN
# 5                       NaN           NaN   1.0
# 6                       NaN           NaN   0.0
# 7                       NaN           NaN   0.0
# 8                       NaN           NaN   0.0
# 9                       NaN           NaN   0.0
# 10                      NaN           NaN   0.0
# 11                      NaN           NaN   NaN
# 12                      NaN           NaN   NaN
# 13                      NaN           NaN   NaN
# 14                      NaN           NaN   0.0
# 15                      NaN           NaN   NaN
# 16                      NaN           NaN   NaN
# 17                      NaN           NaN   0.0
# 18                      NaN           NaN   0.0
# 19                      NaN           NaN   0.0
# 20                      NaN           NaN   NaN
# 21                      NaN           NaN   NaN
# 22                      NaN           NaN   0.0
# 23                      NaN           NaN   NaN
# 24                      NaN           NaN   0.0
# 25                      NaN           NaN   0.0
# 26                      NaN           NaN   0.0
# 27                      NaN           NaN   NaN
# 28                      NaN           NaN   0.0
# 29                      NaN           NaN   NaN
#
#                                          pull_request
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16                                                NaN
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20                                                NaN
# 21                                                NaN
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23                                                NaN
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
# [30 rows x 30 columns]

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/47893  1321666209
# 1     https://github.com/pandas-dev/pandas/pull/47892  1321652312
# 2     https://github.com/pandas-dev/pandas/pull/47891  1321595997
# 3     https://github.com/pandas-dev/pandas/pull/47890  1321593794
# 4     https://github.com/pandas-dev/pandas/pull/47888  1321476198
# 5     https://github.com/pandas-dev/pandas/pull/47887  1321467204
# 6     https://github.com/pandas-dev/pandas/pull/47886  1321439947
# 7     https://github.com/pandas-dev/pandas/pull/47885  1321205130
# 8   https://github.com/pandas-dev/pandas/issues/47884  1321128491
# 9   https://github.com/pandas-dev/pandas/issues/47883  1320820720
# 10  https://github.com/pandas-dev/pandas/issues/47882  1320788915
# 11  https://github.com/pandas-dev/pandas/issues/47880  1320155046
# 12  https://github.com/pandas-dev/pandas/issues/47879  1319991298
# 13  https://github.com/pandas-dev/pandas/issues/47878  1319903400
# 14  https://github.com/pandas-dev/pandas/issues/47874  1319462792
# 15  https://github.com/pandas-dev/pandas/issues/47872  1319315302
# 16  https://github.com/pandas-dev/pandas/issues/47871  1318922970
# 17  https://github.com/pandas-dev/pandas/issues/47867  1318832351
# 18    https://github.com/pandas-dev/pandas/pull/47864  1318472969
# 19  https://github.com/pandas-dev/pandas/issues/47862  1318132972
# 20  https://github.com/pandas-dev/pandas/issues/47861  1318091424
# 21    https://github.com/pandas-dev/pandas/pull/47860  1317996067
# 22  https://github.com/pandas-dev/pandas/issues/47859  1317896982
# 23  https://github.com/pandas-dev/pandas/issues/47856  1317629962
# 24    https://github.com/pandas-dev/pandas/pull/47854  1317571479
# 25  https://github.com/pandas-dev/pandas/issues/47852  1317382511
# 26    https://github.com/pandas-dev/pandas/pull/47849  1317263978
# 27    https://github.com/pandas-dev/pandas/pull/47848  1317038644
# 28    https://github.com/pandas-dev/pandas/pull/47846  1316603513
# 29  https://github.com/pandas-dev/pandas/issues/47845  1316181990
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85Oxwah   47893
# 1   PR_kwDOAA0YD848SaPy   47892
# 2   PR_kwDOAA0YD848SOJX   47891
# 3   PR_kwDOAA0YD848SNrV   47890
# 4   PR_kwDOAA0YD848Rz14   47888
# 5   PR_kwDOAA0YD848Rx2r   47887
# 6   PR_kwDOAA0YD848RrrQ   47886
# 7   PR_kwDOAA0YD848Q4fE   47885
# 8    I_kwDOAA0YD85OvtIr   47884
# 9    I_kwDOAA0YD85Ouh_w   47883
# 10   I_kwDOAA0YD85OuaOz   47882
# 11   I_kwDOAA0YD85Or_em   47880
# 12   I_kwDOAA0YD85OrXgC   47879
# 13   I_kwDOAA0YD85OrCCo   47878
# 14   I_kwDOAA0YD85OpWeI   47874
# 15   I_kwDOAA0YD85Ooydm   47872
# 16   I_kwDOAA0YD85OnSra   47871
# 17   I_kwDOAA0YD85Om8jf   47867
# 18  PR_kwDOAA0YD848H-L3   47864
# 19   I_kwDOAA0YD85OkRzs   47862
# 20   I_kwDOAA0YD85OkHqg   47861
# 21  PR_kwDOAA0YD848GYzX   47860
# 22   I_kwDOAA0YD85OjYMW   47859
# 23   I_kwDOAA0YD85OiXAK   47856
# 24  PR_kwDOAA0YD848FAXw   47854
# 25   I_kwDOAA0YD85Ohalv   47852
# 26  PR_kwDOAA0YD848D_Xy   47849
# 27  PR_kwDOAA0YD848DPub   47848
# 28  PR_kwDOAA0YD848Bypx   47846
# 29   I_kwDOAA0YD85Oc1fm   47845
#
#                                                 title  ... closed_at  \
# 0         BUG: take with MultiIndex duplicating index  ...       NaT
# 1               CLN: Rename "add" to "sum" in groupby  ...       NaT
# 2   Backport PR #47889 on branch 1.4.x (CI: Pin cy...  ...       NaT
# 3                        CI: Add CodeQL Github Action  ...       NaT
# 4                 REF: Rename exchange -> interchange  ...       NaT
# 5   REF: Change _NULL_DESCRIPTION[datetime] to use...  ...       NaT
# 6   REF: PandasColumn.describe_categorical returns...  ...       NaT
# 7                   DOC: Add numpydoc SS06 validation  ...       NaT
# 8   Pandas string dtype needs from NumPy - prototy...  ...       NaT
# 9   BUG: Unexpected results when adding offsets to...  ...       NaT
# 10  BUG: FutureWarning for timezone-naive date tim...  ...       NaT
# 11            ENH: parse 8 or 9 digit delimited dates  ...       NaT
# 12  PERF: preserve Index._id through pickle round-...  ...       NaT
# 13  PERF: MultiIndex.copy(deep=False) not preservi...  ...       NaT
# 14  BUG: `to_sql` string to date and/or time conve...  ...       NaT
# 15  ENH: Allow different `dtype` in `pandas.Series...  ...       NaT
# 16  BUG: to_csv requires escapechar unnecessarily ...  ...       NaT
# 17  BUG: Update Values from MultiIndex Dataframe a...  ...       NaT
# 18  ENH: `Styler.relabel_index` for directly speci...  ...       NaT
# 19  DEPR or DOCS:   pd.value_counts() is public, b...  ...       NaT
# 20      DOC: Plotting / Visualization without Jupyter  ...       NaT
# 21  Added improvements in to_datetime Error report...  ...       NaT
# 22  ENH: DataFrame eval will not work with '"True"...  ...       NaT
# 23  BUG: The `nanoseconds` in pd.DateOffset was ig...  ...       NaT
# 24  DOC/ENH: Add documentation and whatsnew entry ...  ...       NaT
# 25  ENH: Adding functionality to ignore certain co...  ...       NaT
# 26  Added improvements in to_datetime Error report...  ...       NaT
# 27  Fix styling of `DataFrame` for columns with bo...  ...       NaT
# 28  DOC: Clarify sorting and order of categoricals...  ...       NaT
# 29  ENH: Add more "Offset aliases" to Timedelta fu...  ...       NaT
#
#    author_association active_lock_reason  \
# 0                NONE                NaN
# 1              MEMBER                NaN
# 2                NONE                NaN
# 3              MEMBER                NaN
# 4              MEMBER                NaN
# 5              MEMBER                NaN
# 6              MEMBER                NaN
# 7              MEMBER                NaN
# 8                NONE                NaN
# 9                NONE                NaN
# 10               NONE                NaN
# 11             MEMBER                NaN
# 12             MEMBER                NaN
# 13             MEMBER                NaN
# 14               NONE                NaN
# 15               NONE                NaN
# 16        CONTRIBUTOR                NaN
# 17               NONE                NaN
# 18        CONTRIBUTOR                NaN
# 19        CONTRIBUTOR                NaN
# 20               NONE                NaN
# 21        CONTRIBUTOR                NaN
# 22        CONTRIBUTOR                NaN
# 23               NONE                NaN
# 24             MEMBER                NaN
# 25               NONE                NaN
# 26        CONTRIBUTOR                NaN
# 27               NONE                NaN
# 28        CONTRIBUTOR                NaN
# 29               NONE                NaN
#
#                                                  body  \
# 0   ### Pandas version checks\n\n- [X] I have chec...
# 1   - [ ] closes #xxxx (Replace xxxx with the Gith...
# 2   Backport PR #47889: CI: Pin cython on 32bit build
# 3   Similar to Ibis' configuration: https://github...
# 4                      Recommended by @vnlitvinov\r\n
# 5   - [x] [Tests added and passed](https://pandas....
# 6   - [x] [Tests added and passed](https://pandas....
# 7   - [x] closes #29254 (Replace xxxx with the Git...
# 8   The purpose of this issue is to discuss a plan...
# 9   ### Pandas version checks\n\n- [X] I have chec...
# 10  ### Pandas version checks\r\n\r\n- [X] I have ...
# 11  ### Feature Type\n\n- [ ] Adding new functiona...
# 12  ### Pandas version checks\r\n\r\n- [X] I have ...
# 13  ### Pandas version checks\n\n- [X] I have chec...
# 14  ### Pandas version checks\r\n\r\n- [X] I have ...
# 15  ### Feature Type\n\n- [X] Adding new functiona...
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  ### Pandas version checks\r\n\r\n- [X] I have ...
# 18  \r\n<img width="645" alt="Screenshot 2022-07-2...
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  ### Pandas version checks\n\n- [X] I have chec...
# 21  Splitting changes from #47597, This PR aims to...
# 22  ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  - [ ] [Tests added and passed](https://pandas....
# 25  ### Feature Type\n\n- [X] Adding new functiona...
# 26  Splitting changes from #47597, This PR aims to...
# 27  - [x] closes #47838\r\n- [x] [Tests added and ...
# 28  Without the addition in the text it‘s unclear,...
# 29  ### Feature Type\n\n- [ ] Adding new functiona...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason draft  \
# 0                       NaN           NaN   NaN
# 1                       NaN           NaN   0.0
# 2                       NaN           NaN   0.0
# 3                       NaN           NaN   0.0
# 4                       NaN           NaN   0.0
# 5                       NaN           NaN   0.0
# 6                       NaN           NaN   0.0
# 7                       NaN           NaN   0.0
# 8                       NaN           NaN   NaN
# 9                       NaN           NaN   NaN
# 10                      NaN           NaN   NaN
# 11                      NaN           NaN   NaN
# 12                      NaN           NaN   NaN
# 13                      NaN           NaN   NaN
# 14                      NaN           NaN   NaN
# 15                      NaN           NaN   NaN
# 16                      NaN           NaN   NaN
# 17                      NaN           NaN   NaN
# 18                      NaN           NaN   0.0
# 19                      NaN           NaN   NaN
# 20                      NaN           NaN   NaN
# 21                      NaN           NaN   1.0
# 22                      NaN           NaN   NaN
# 23                      NaN           NaN   NaN
# 24                      NaN           NaN   0.0
# 25                      NaN           NaN   NaN
# 26                      NaN           NaN   1.0
# 27                      NaN           NaN   0.0
# 28                      NaN           NaN   0.0
# 29                      NaN           NaN   NaN
#
#                                          pull_request
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19                                                NaN
# 20                                                NaN
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22                                                NaN
# 23                                                NaN
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
# [30 rows x 30 columns]

# %%
json_data.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
json_data['user']
# Out:
# 0     {'login': 'joooeey', 'id': 28426758, 'node_id'...
# 1     {'login': 'vranoch', 'id': 51007145, 'node_id'...
# 2     {'login': 'pjousma', 'id': 114391084, 'node_id...
# 3     {'login': 'killerrex', 'id': 1187546, 'node_id...
# 4     {'login': 'mrileysamc', 'id': 105988873, 'node...
# 5     {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 6     {'login': 'bashtage', 'id': 5585221, 'node_id'...
# 7     {'login': 'DriesSchaumont', 'id': 5946712, 'no...
# 8     {'login': 'JanVHII', 'id': 12532395, 'node_id'...
# 9     {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 10    {'login': 'Himanshuwagh', 'id': 76431630, 'nod...
# 11    {'login': 'gtopper', 'id': 4675524, 'node_id':...
# 12    {'login': 'StevenLi-DS', 'id': 33796896, 'node...
# 13    {'login': 'mrfrizzz', 'id': 113800322, 'node_i...
# 14    {'login': 'jonashaag', 'id': 175722, 'node_id'...
# 15    {'login': 'gravesee', 'id': 1675613, 'node_id'...
# 16    {'login': 'datapythonista', 'id': 10058240, 'n...
# 17    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 18    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 19    {'login': 'HebiKotei', 'id': 13180679, 'node_i...
# 20    {'login': 'datapythonista', 'id': 10058240, 'n...
# 21    {'login': 'ruifeng96150', 'id': 17608115, 'nod...
# 22    {'login': 'llamington', 'id': 54869395, 'node_...
# 23    {'login': 'tdpetrou', 'id': 7226751, 'node_id'...
# 24    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 25    {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 26    {'login': 'datapythonista', 'id': 10058240, 'n...
# 27    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 28    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 29    {'login': 'aulemahal', 'id': 20629530, 'node_i...
# Name: user, dtype: object

# %%
#Unwrapping dictionary of dictionary
json_data['user'][0]
# Out:
# {'login': 'joooeey',
#  'id': 28426758,
#  'node_id': 'MDQ6VXNlcjI4NDI2NzU4',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/28426758?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/joooeey',
#  'html_url': 'https://github.com/joooeey',
#  'followers_url': 'https://api.github.com/users/joooeey/followers',
#  'following_url': 'https://api.github.com/users/joooeey/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/joooeey/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/joooeey/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/joooeey/subscriptions',
#  'organizations_url': 'https://api.github.com/users/joooeey/orgs',
#  'repos_url': 'https://api.github.com/users/joooeey/repos',
#  'events_url': 'https://api.github.com/users/joooeey/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/joooeey/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
#Converting dataframe into json
attribute_data.to_json('Attribute Data_JSON')

# %%
#pwd #Present Working Directory
#Spark Dataframe is faster than Pandas Dataframe because it uses optimizer internally.

# %%
#Saving Data in form of csv,excel etc
attribute_data.to_csv("CSV Attribute Data.csv") #Give the relevant path with filename if we dont want to store in present working directory
attribute_data.to_json("JSON Attribute Data.json")
attribute_data.to_excel("Excel Attribute Data.xlsx")
attribute_data.to_csv("Attribute Data1.csv",sep = '@') #If we want to change the delimiter, we can use separator parameter
attribute_data.to_csv("Attribute Data2.csv",sep = '#')
attribute_data.to_csv("Attribute Data3.csv",sep = '#', index = False) #Row Index will be removed from our saved file

# %% [markdown]
# ## TASK
# We have Attribute Dataset and Dress Sales Dataset. These are connected to each other based on Dress_ID. Perform the Following Task:
#
# 1.Create a Table of attribute dataset and dress dataset in mysql workbench/python
#
# 2.Do a bulk load for these 2 tables for respective dataset in mysql workbench/python
#
# 3.Read these datasets in pandas as a dataframe
#
# 4.Convert Attribute Dataset in JSON Format (.to_json will be used)
#
# 5.Store this json dataset into mongodb (Insert_many will be used)
#
# 6.In SQL task, try to perform left join operation with Attribute dataset and dress dataset on column
# Dress_ID
# 7.Write the SQL query to find out how many unique dress that we have based on Dress_ID
#
# 8.Try to find out how many dress is having recommendation as 0
#
# 9.Try to find out total dress sales for each and every Dress_ID
#
# 10Try to find out the third highest most selling Dress_ID
